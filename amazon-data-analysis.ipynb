# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/amazon-sales-dataset/amazon.csv

# %% [markdown]
# # My Other Most Upvoted Notebooks:
# #### Visit My Website Codersaim.com for more.
# #### ** Please Upvote If You Find the Notebook Helpful **
#
# * [**All Necessary Code of Pandas**](https://www.kaggle.com/code/rafsunahmad/all-necessary-code-of-pandas)
# * [**Everything About EDA Using Seaborn & Matplotlib**](https://www.kaggle.com/code/rafsunahmad/everything-about-eda-using-seaborn-matplotlib)
# * [**Full Guide Feature Scaling Theory + Code**](https://www.kaggle.com/code/rafsunahmad/full-guide-feature-scaling)
# * [**Popular Regression Algorithms Theory + Code**](https://www.kaggle.com/code/rafsunahmad/regression-algorithms-theory-code)
# * [**Popular Classification Algorithms Theory + Code**](https://www.kaggle.com/code/rafsunahmad/classification-algorithms-theory-code)
# * [**Everything About Multicollinearity Theory + Code**](https://www.kaggle.com/code/rafsunahmad/everything-about-multicollinearity-theory-code)
# * [**Common Features Selection Methods Theory + Code**](https://www.kaggle.com/code/rafsunahmad/common-features-selection-methods-theory-code)
# * [**All Model Evaluation Techniques Theory + Code**](https://www.kaggle.com/code/rafsunahmad/all-model-evaluation-techniques-theory-code)
# * [**All Popular Clustering Methods Theory + Code**](https://www.kaggle.com/code/rafsunahmad/all-popular-clustering-methods-theory-code)
# * [**Cross Validation All Techniques Theory + Code**](https://www.kaggle.com/code/rafsunahmad/cross-validation-all-techniques-theory-code)
# * [**All Ensemble Learning Methods Theory + Code**](https://www.kaggle.com/code/rafsunahmad/all-ensemble-learning-methods-theory-code)
# * [**ANN Ultimate Guide( All You Need to Know)**](https://www.kaggle.com/code/rafsunahmad/ann-ultimate-guide-all-you-need-to-know)
# * [**CNN Ultimate Guide( All You Need to Know)**](https://www.kaggle.com/code/rafsunahmad/cnn-ultimate-guide-all-you-need-to-know)
# * [**VGG16 & Alex net Working Process Guide**](https://www.kaggle.com/code/rafsunahmad/vgg16-alex-net-working-process-guide)
# * [**RNN Ultimate Guide( All You Need to Know)**](https://www.kaggle.com/code/rafsunahmad/rnn-ultimate-guide-all-you-need-to-know)
# * [**Transformer Model Complete Guide**](https://www.kaggle.com/code/rafsunahmad/transformer-model-complete-guide)
# * [**Amazon Data Analysis**](https://www.kaggle.com/code/rafsunahmad/amazon-data-analysis)
# * [**News Category Classifier Accuracy-83%**](https://www.kaggle.com/code/rafsunahmad/news-category-classifier-accuracy-83)
# * [**Australian Vehicle Prices Prediction accuracy=86%**](https://www.kaggle.com/code/rafsunahmad/australian-vehicle-prices-prediction-accuracy-86)
# * [**Terrorist Attack Complete EDA**](https://www.kaggle.com/code/rafsunahmad/terrorist-attack-complete-eda)
# * [**Customer Behavior Classification + EDA**](https://www.kaggle.com/code/rafsunahmad/customer-behavior-classification-eda)
# * [**Heart Disease Complete EDA + accuracy =98%**](https://www.kaggle.com/code/rafsunahmad/heart-disease-complete-eda-accuracy-98)

# %%
df=pd.read_csv('/kaggle/input/amazon-sales-dataset/amazon.csv')
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
df.shape
# Out:
# (1465, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
#  15  product_link         1465 non-null   object
# dtypes: object(16)
# memory usage: 183.2+ KB

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ##### Checking for missing values

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# product_id             0.000000
# product_name           0.000000
# category               0.000000
# discounted_price       0.000000
# actual_price           0.000000
# discount_percentage    0.000000
# rating                 0.000000
# rating_count           0.136519
# about_product          0.000000
# user_id                0.000000
# user_name              0.000000
# review_id              0.000000
# review_title           0.000000
# review_content         0.000000
# img_link               0.000000
# product_link           0.000000
# dtype: float64

# %% [markdown]
# ##### Dropping some columns

# %%
df.drop(['product_id','user_id','user_name','review_id','img_link','product_link'], axis=1, inplace=True)
df.head()
# Out:
#                                         product_name  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...

# %%
df=df.dropna()

# %% [markdown]
# ##### Replacing and convert into correct data type

# %%
df['actual_price'] = df['actual_price'].str.replace('₹', '').str.replace(',', '')
df['actual_price'] = df['actual_price'].astype(float)

df['discounted_price'] = df['discounted_price'].str.replace('₹', '').str.replace(',', '')
df['discounted_price'] = df['discounted_price'].astype(float)

df['discount_percentage'] = df['discount_percentage'].str.replace('%', '')
df['discount_percentage'] = df['discount_percentage'].astype(int)

df['rating_count'] = df['rating_count'].str.replace(',', '')
df['rating_count'] = df['rating_count'].astype(int)

df['rating'] = df['rating'].replace('|', np.nan)
df['rating'] = df['rating'].astype(float)


df.head()
# Out:
#                                         product_name  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                   64     4.2         24269
# 1         349.0                   43     4.0         43994
# 2        1899.0                   90     3.9          7928
# 3         699.0                   53     4.2         94363
# 4         399.0                   61     4.2         16905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...

# %% [markdown]
# ##### Dropping missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1463 entries, 0 to 1464
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_name         1463 non-null   object
#  1   category             1463 non-null   object
#  2   discounted_price     1463 non-null   float64
#  3   actual_price         1463 non-null   float64
#  4   discount_percentage  1463 non-null   int64
#  5   rating               1462 non-null   float64
#  6   rating_count         1463 non-null   int64
#  7   about_product        1463 non-null   object
#  8   review_title         1463 non-null   object
#  9   review_content       1463 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 125.7+ KB

# %% [markdown]
# # Creating some new features

# %% [markdown]
# ##### Splitting category column and creating four new categories

# %%
df_cat = df['category'].str.split('|', expand=True).rename(columns={0:'category_1', 1:'category_2', 2:'category_3', 3:'category_4',4:'category_5'})
 
df['category_1'] = df_cat['category_1']
df['category_2'] = df_cat['category_2']
df['category_3'] = df_cat['category_3']
df['category_4'] = df_cat['category_4']

df.drop('category', axis=1, inplace=True)
df.head()
# Out:
#                                         product_name  discounted_price  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...             399.0
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...             199.0
# 2  Sounce Fast Phone Charging Cable & Data Sync U...             199.0
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             329.0
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                   64     4.2         24269
# 1         349.0                   43     4.0         43994
# 2        1899.0                   90     3.9          7928
# 3         699.0                   53     4.2         94363
# 4         399.0                   61     4.2         16905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_
# 177   【High Charging Speed 65W】: Output power up to ...
# 261   Usb c to usb a data charging cable, fully comp...
# 1425  Plastic+Adhesive Paper|Practical handle with h...
# 352   The perfect way to add some style and stand ou...
# 714   Resolution: HD Ready (1366x768) | Refresh Rate...
# 318   [ Amazon Fire Tv Stick Remote ] New Replacemen...
# 582   Compatibility: The Dyazo OTG USB is universall...
# 562   Connect USB Type-C enabled devices (MacBook, C...
# 59    MORE DURABLE- Konnect L Micro cable is unique ...
# 202   Replacement for Sony RM-YD092 ,Fits with vario...
# 275   100% Best Quality Plastic Body and Soft Silico...
# 309   NYLON BRAIDED, EXTREME DURABILITY: with a test...
# 321   Resolution: HD Ready Android TV (1366x768) | R...
# 227   The Rts (Radhey Techno Servies) High Speed HDM...
# 295   Resolution : Ultra HD 4k (3840 X 2160) resolut...
# 400   The perfect way to add some style and stand ou...
# 984   50 assorted shades + 1 scraping tool|Confirms ...
# 1435  PACKAGE CONTAIN: 1 Piece Laundry Basket|MATERI...
# 1120  Warranty: 1 year on product|Power: 600 watts ;...
# 853   Modern, slim and beautiful Pebble shape Logite...
# 584   The perfect way to add some style and stand ou...
# 829   This is a polarized power cable designed to co...
# 523   In Ear Volume Control. Water Resistant: Yes|De...
# 614   High Compatibility : Compatible With iPhone 12...
# 594   Sharp and bright display: The 1.69’’ TFT displ...
# 303   [NOTE - >>Not Support to DVR and HDTV]..[CONNE...
# 368   Fire-Boltt is India' No 1 Wearable Watch Brand...
# 9     Universal Compatibility – It is compatible wit...
# 1155  CLASSIC DESIGN : The classical mirror polish o...
# 1273  Quickly removes lint, dust, dandruff and pet h...
# 654   Compatible: Wd, Seagate, Sony, Transcend, ADAT...
# 603   PTron bullet pro is a 36w charging power car c...
# 1298  Quick and efficient Switch to turn it on and g...
# 777   Compact Design Line Interactive UPS with Load ...
# 180   Soft & Durable Keypad Durable Quality|Rigid Bo...
# 536   With 40mm Drivers get ready to immerse in HD a...
# 997   The side the LED light falls on will depend on...
# 219   The boAt LTG 550v3 Apple MFi Certified Lightni...
# 1189  Consumes Lower Gas|Even Distribution Of Heat|C...
# 700   Supports Ios Devices With Max Output Up To 2.4...
# 264   Type: HDMI|Power Requirement: DC 5 V|Number of...
# 193   Compatible Device For VU LED LCD HD Tv Remote ...
# 1084  PRODUCT: Crompton's energy efficient storage w...
# 63    Connect Usb Type-C Enabled Devices (Macbook, C...
# 693   The all-metal, 2-in-1 flash drive with a rever...
# 561   Compatible Device: iPhone 13 / iPhone 13 Pro /...
# 499   Processor: MediaTek Dimensity 810 Octa-core 5G...
# 267   Nylon-braided HDMI cable (A Male to A Male): s...
# 136   Fast Charging - All combined 3-in-1 USB cable ...
#
#                                            review_title  \
# 253   Worked on iPhone 7 and didn’t work on XR,Good ...
# 177   Changing speed,Make it better,Superb Build Qua...
# 261   Nice product .,Good quality Braided cable, VFM...
# 1425  Great Product!!,Good product,Adhesion,Amazing ...
# 352   Best value for money,HEAD PHONE POUCH NOT RECE...
# 714   Sound quality,Very nice,Value for money,Good,G...
# 318   Good, But Disappointed,Perfect replacement,Hav...
# 582   Good,Good,Worth buying and easy to use,Good,Gr...
# 562   You can trust on this one,The best usb cable,W...
# 59    It's working,It's gud 😳,Cable quality is good....
# 202   Excellent solution for Sony TVs,Worth purchase...
# 275   When I placed the order I was in doubt whether...
# 309   Good And Durable,Value for money product.,Righ...
# 321   Nice tv,Good product,Average,No operation butt...
# 227   Good quality but not superb,Good,Good,Not work...
# 295   Good value for money,Good,Kodak Tv,One side of...
# 400   Best value for money,HEAD PHONE POUCH NOT RECE...
# 984   Good product,Decent,Highly recommended,Kids lo...
# 1435  Worth Buying,Utility product,Good one,Average,...
# 1120  Nice product,Best for hostel guys,Easy to hand...
# 853   Sleek and battery efficient!,It's made for erg...
# 584   Best value for money,HEAD PHONE POUCH NOT RECE...
# 829   Good product, Cheap and works well,good one,Ni...
# 523   Works well, but not for long,Good product,Good...
# 614   Satisfied,Charging is really fast,Value for mo...
# 594   Sumit Nath,For the price, it is a good purchas...
# 303   Thank you,Satisfying product,Keeps disconnecti...
# 368   Worth the money,Good smart watch,the screen do...
# 9     A Good Braided Cable for Your Type C Device,Go...
# 1155  Useful,Not value for money,कीमत के हिसाब से बे...
# 1273  Good to use,Really good in this price,Lint rol...
# 654   Good.No Problem,Good Product,value for money p...
# 603   Good,Good product,Charging well but build qual...
# 1298  Good,It's a good product. Go for it.,Easy to u...
# 777   Most featured UPS,Not Sufficient for a 65" Son...
# 180   Poor plastic Material but it works.,Very cheap...
# 536   Worth Every Square Inch.,VFM, Plastic build. M...
# 997   it worked properly for almost one year,ok,USB ...
# 219   Low quality material use,Good one,Cable is goo...
# 1189  Value for money,Just worth it ....,verry usefu...
# 700   Good cable for car,Good substitute for orginal...
# 264   Great Product,Very good and working very nice,...
# 193   Works just fine for my vu tv,Quality to be imp...
# 1084  Product is good but the installation provider ...
# 63    Its ok product not too good not bad,Cheap and ...
# 693   Ya Nice..value for money..,Overall decent Prod...
# 561   Great product if you don’t mind the edges,Reco...
# 499   Good 5g mobile,Overall good phone,The best pho...
# 267   Satisfactory,Superb88,Good hdmi cable for 1080...
# 136   The metal pin is losing it's strength,Sahi h b...
#
#                                          review_content  \
# 253   Worked on iPhone 7 and didn’t work on iPhone X...
# 177   The product was nice its charging awesome,Cant...
# 261   Sturdy packing, good product!,Have used this b...
# 1425  ,It's easy to use, one sheet for one dress. Ad...
# 352   The sound quality of this earphone are really ...
# 714   LG was always Good , correct delivery, good se...
# 318   Volume Buttons, Mute & Power off options not w...
# 582   Works the purpose of OTG for samsung galaxy A7...
# 562   Previously bought amazon basic USB type A cabl...
# 59    Working fine,very good this data cable,Perform...
# 202   Sometimes its simple solutions that come to re...
# 275   Ok,Very disappointedRange is not good it doesn...
# 309   Purcahsed 2 pieces. Supports fast charing, goo...
# 321   Good quality,Good product,Average,No operation...
# 227   Like ok,Product as specified,Good,,Yes it's ve...
# 295   It's a good tv with a picture and sound exceed...
# 400   The sound quality of this earphone are really ...
# 1298           Home&Kitchen          Kitchen&HomeAppliances
# 777   Computers&Accessories         Accessories&Peripherals
# 180             Electronics            HomeTheater,TV&Video
# 536             Electronics  Headphones,Earbuds&Accessories
# 997   Computers&Accessories         Accessories&Peripherals
# 219   Computers&Accessories         Accessories&Peripherals
# 1189           Home&Kitchen          Kitchen&HomeAppliances
# 700   Computers&Accessories         Accessories&Peripherals
# 264             Electronics                       HomeAudio
# 193             Electronics            HomeTheater,TV&Video
# 1084           Home&Kitchen      Heating,Cooling&AirQuality
# 63    Computers&Accessories         Accessories&Peripherals
# 693   Computers&Accessories     ExternalDevices&DataStorage
# 561             Electronics             Mobiles&Accessories
# 499             Electronics             Mobiles&Accessories
# 267             Electronics            HomeTheater,TV&Video
# 136   Computers&Accessories         Accessories&Peripherals
#
#                        category_3                    category_4
# 253            Cables&Accessories                        Cables
# 177            Cables&Accessories                        Cables
# 261            Cables&Accessories                        Cables
# 1425      Vacuum,Cleaning&Ironing    Irons,Steamers&Accessories
# 352                    Headphones                        In-Ear
# 714                   Televisions              SmartTelevisions
# 318                   Accessories                RemoteControls
# 582             MobileAccessories               Cables&Adapters
# 562            Cables&Accessories                        Cables
# 59             Cables&Accessories                        Cables
# 202                   Accessories                RemoteControls
# 275                   Accessories                RemoteControls
# 309            Cables&Accessories                        Cables
# 321                   Televisions              SmartTelevisions
# 227                   Accessories                        Cables
# 295                   Televisions              SmartTelevisions
# 400                    Headphones                        In-Ear
# 984             PaintingMaterials                          None
# 1435          LaundryOrganization                LaundryBaskets
# 1120       SmallKitchenAppliances    Kettles&HotWaterDispensers
# 853   Keyboards,Mice&InputDevices                          Mice
# 584                    Headphones                        In-Ear
# 829             LaptopAccessories  LaptopChargers&PowerSupplies
# 523                    Headphones                        In-Ear
# 614            Cables&Accessories                        Cables
# 594                  SmartWatches                          None
# 303               NetworkAdapters           WirelessUSBAdapters
# 368                  SmartWatches                          None
# 9              Cables&Accessories                        Cables
# 1155       SmallKitchenAppliances    Kettles&HotWaterDispensers
# 1273      Vacuum,Cleaning&Ironing    Irons,Steamers&Accessories
# 654                  HardDiskBags                          None
# 603             MobileAccessories                      Chargers
# 1298      Vacuum,Cleaning&Ironing    Irons,Steamers&Accessories
# 777    UninterruptedPowerSupplies                          None
# 180                   Accessories                RemoteControls
# 536                    Headphones                        On-Ear
# 997                    USBGadgets                         Lamps
# 219            Cables&Accessories                        Cables
# 1189       SmallKitchenAppliances                SandwichMakers
# 700            Cables&Accessories                        Cables
# 264         MediaStreamingDevices              StreamingClients
# 193                   Accessories                RemoteControls
# 1084         WaterHeaters&Geysers           StorageWaterHeaters
# 63             Cables&Accessories                        Cables
# 693                     PenDrives                          None
# 561             MobileAccessories    Maintenance,Upkeep&Repairs
# 499      Smartphones&BasicMobiles                   Smartphones
# 267                   Accessories                        Cables
# 136            Cables&Accessories                        Cables

# %%
df.isnull().sum()
# Out:
# product_name             0
# discounted_price         0
# actual_price             0
# discount_percentage      0
# rating                   1
# rating_count             0
# about_product            0
# review_title             0
# review_content           0
# category_1               0
# category_2               0
# category_3               8
# category_4             165
# dtype: int64

# %%
df=df.dropna()

# %%
df['Price']=df['discounted_price']*df['rating_count']
df['Price']
# Out:
# 0        9683331.0
# 1        8754806.0
# 2        1577672.0
# 3       31045427.0
# 4        2603370.0
#            ...
# 1460      413110.0
# 1461     9389040.0
# 1462     1038492.0
# 1463    11235369.0
# 1464    20003781.0
# Name: Price, Length: 1297, dtype: float64

# %% [markdown]
# # EDA

# %% [markdown]
# ##### Average, Minimum and Maximum Rating of category

# %%
result1 = df.groupby('category_3')['rating'].agg(['mean', 'min', 'max'])
result1['mean'] = result1['mean'].round(2)
result1
# Out:
#                              mean  min  max
# category_3
# Accessories                  4.00  3.0  4.6
# Adapters                     4.15  4.0  4.3
# AirConditioners              4.30  4.3  4.3
# AirPurifiers                 4.28  4.1  4.4
# Audio&VideoAccessories       3.89  3.3  4.3
# Cables&Accessories           4.15  3.3  5.0
# Calculators                  4.45  4.4  4.5
# Coffee,Tea&Espresso          4.01  3.3  4.5
# Drawing&PaintingSupplies     4.30  4.3  4.3
# DrawingMaterials             4.35  4.3  4.4
# Fans                         4.09  3.8  4.3
# Flashes                      3.80  3.8  3.8
# HardDriveAccessories         4.10  4.1  4.1
# Headphones                   3.92  3.4  4.2
# HealthMonitors               4.00  4.0  4.0
# Inks,Toners&Cartridges       4.23  4.0  4.4
# InteriorAccessories          3.80  3.8  3.8
# Keyboards,Mice&InputDevices  4.16  3.3  5.0
# KitchenTools                 4.10  4.1  4.1
# LaptopAccessories            4.13  3.5  4.5
# LaundryOrganization          4.03  3.7  4.3
# MediaStreamingDevices        4.50  4.5  4.5
# MemoryCards                  4.34  4.0  4.5
# MobileAccessories            4.17  3.6  4.7
# NetworkAdapters              4.12  3.4  4.5
# PCGamingPeripherals          4.29  3.8  4.6
# PaintingMaterials            4.43  4.4  4.5
# Paper                        4.29  4.0  4.5
# Parts&Accessories            4.10  4.1  4.1
# Printers                     3.60  3.4  3.8
# RoomHeaters                  3.83  2.0  4.6
# SatelliteEquipment           4.27  4.2  4.3
# Scrapbooking                 3.90  3.9  3.9
# SecurityCameras              4.10  3.8  4.3
# SewingMachines&Accessories   3.65  3.1  4.3
# SmallKitchenAppliances       4.05  2.3  4.8
# Smartphones&BasicMobiles     4.08  3.5  4.4
# Speakers                     4.02  3.7  4.3
# TabletAccessories            4.20  4.0  4.5
# Televisions                  4.20  3.4  4.7
# USBGadgets                   3.94  3.6  4.3
# Vacuum,Cleaning&Ironing      4.08  3.1  4.6
# WaterHeaters&Geysers         4.08  3.4  4.8
# WaterPurifiers&Accessories   4.05  2.9  4.6

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Plotting line plot for min and max ratings
result1[['min', 'mean','max']].plot(kind='line', marker='o')

# Set titles and labels
plt.title('Ratings Summary by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Avg, min, max rating')
plt.legend()
plt.xticks(rotation=45)
# Show the plots
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'result' DataFrame contains the aggregated data

# Plotting a single bar chart for mean, min, and max ratings
result1.plot(kind='bar', color=['skyblue', 'lightgreen', 'salmon'])

# Set titles and labels
plt.title('Ratings Summary by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Rating')
plt.legend(['Mean Rating', 'Min Rating', 'Max Rating'])

# Show the plot
plt.show()

# %% [markdown]
# ##### Maximum, minimum and average discount percentage on a category

# %%
result1 = df.groupby('category_3')['discount_percentage'].agg(['mean', 'min', 'max'])
result1['mean'] = result1['mean'].round(2)
result1
# Out:
#                               mean  min  max
# category_3
# Accessories                  56.93    0   88
# Adapters                     78.50   63   94
# AirConditioners              43.00   43   43
# AirPurifiers                 41.00   23   76
# Audio&VideoAccessories       47.14   23   66
# Cables&Accessories           59.57    0   90
# Calculators                   1.25    0    5
# Coffee,Tea&Espresso          41.93   17   60
# Drawing&PaintingSupplies      0.00    0    0
# DrawingMaterials              5.00    0   10
# Fans                         36.35   15   58
# Flashes                      60.00   60   60
# HardDriveAccessories         75.00   75   75
# Headphones                   57.85    0   85
# HealthMonitors               53.00   53   53
# Inks,Toners&Cartridges       28.83    4   73
# InteriorAccessories          42.00   42   42
# Keyboards,Mice&InputDevices  47.32    8   88
# KitchenTools                 60.00   60   60
# LaptopAccessories            57.42    0   85
# LaundryOrganization          46.06   11   68
# MediaStreamingDevices         0.00    0    0
# MemoryCards                  57.79   43   77
# MobileAccessories            60.99    7   90
# NetworkAdapters              47.85   17   78
# PCGamingPeripherals          43.00   14   79
# PaintingMaterials             9.33    0   15
# Paper                        14.00    0   75
# Parts&Accessories            59.00   59   59
# Printers                     11.50   10   13
# RoomHeaters                  38.23    4   67
# SatelliteEquipment           51.33   46   60
# Scrapbooking                 21.00   21   21
# SecurityCameras              42.60   24   69
# SewingMachines&Accessories   40.50   19   52
# SmallKitchenAppliances       41.19    0   90
# Smartphones&BasicMobiles     22.74    0   49
# Speakers                     50.54   25   70
# TabletAccessories            66.25   23   78
# Televisions                  39.49    0   65
# USBGadgets                   16.00    0   70
# Vacuum,Cleaning&Ironing      39.14    3   80
# WaterHeaters&Geysers         43.91    7   71
# WaterPurifiers&Accessories   37.23    0   86

# %%
result1.reset_index(inplace=True)

# Plotting a bar chart using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='category_3', y='mean', data=result1, color='skyblue', label='Mean')
sns.barplot(x='category_3', y='max', data=result1, color='salmon', alpha=0.7, label='Max')
sns.barplot(x='category_3', y='min', data=result1, color='lightgreen', alpha=0.6, label='Min')

# Set titles and labels
plt.title('Discount Percentage Summary by Category')
plt.xlabel('Category')
plt.ylabel('Discount Percentage')
plt.legend()

# Show the plot
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#                                         product_name  discounted_price  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...             399.0
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...             199.0
# 2  Sounce Fast Phone Charging Cable & Data Sync U...             199.0
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             329.0
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                   64     4.2         24269
# 1         349.0                   43     4.0         43994
# 2        1899.0                   90     3.9          7928
# 3         699.0                   53     4.2         94363
# 4         399.0                   61     4.2         16905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content             category_1  \
# 0  Looks durable Charging is fine tooNo complains...  Computers&Accessories
# 1  I ordered this cable to connect my phone to An...  Computers&Accessories
# 2  Not quite durable and sturdy,https://m.media-a...  Computers&Accessories
# 3  Good product,long wire,Charges good,Nice,I bou...  Computers&Accessories
# 4  Bought this instead of original apple, does th...  Computers&Accessories
#
#                 category_2          category_3 category_4       Price
# 0  Accessories&Peripherals  Cables&Accessories     Cables   9683331.0
# 1  Accessories&Peripherals  Cables&Accessories     Cables   8754806.0
# 2  Accessories&Peripherals  Cables&Accessories     Cables   1577672.0
# 3  Accessories&Peripherals  Cables&Accessories     Cables  31045427.0
# 4  Accessories&Peripherals  Cables&Accessories     Cables   2603370.0

# %% [markdown]
# ##### Count of each category

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='category_3', data=df, palette='viridis')
plt.title('Distribution of Categories')
plt.xlabel('Category')
plt.ylabel('Count')

plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Top 20 category got most of the review

# %%
x=df[['category_3','rating_count']]
xx = x.sort_values(by='rating_count', ascending=False)
xx.reset_index(inplace=True,drop=True)
xx.head(20)
# Out:
#                   category_3  rating_count
# 0                Accessories        426973
# 1                Accessories        426973
# 2                Accessories        426973
# 3                Accessories        426972
# 4                 Headphones        363713
# 5                 Headphones        363713
# 6                 Headphones        363711
# 7   Smartphones&BasicMobiles        313836
# 8   Smartphones&BasicMobiles        313836
# 9   Smartphones&BasicMobiles        313832
# 10  Smartphones&BasicMobiles        313832
# 11                Headphones        273189
# 12              KitchenTools        270563
# 13               MemoryCards        205052
# 14                Headphones        192590
# 15                Headphones        192589
# 16                Headphones        192587
# 17                Headphones        180998
# 18           NetworkAdapters        179692
# 19           NetworkAdapters        179691

# %%
data1=xx.loc[0:19]
plt.figure(figsize=(10, 6))
sns.barplot(x='rating_count', y='category_3', data=data1, palette='viridis',orient='h')

plt.title('Top 20 Ratings by Category')
plt.xlabel('Category')
plt.ylabel('Rating Count')

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
##### Top 20 highest rated category

# %%
x=df[['category_3','rating']]
xx = x.sort_values(by='rating', ascending=False)
xx.reset_index(inplace=True,drop=True)
xx.head(20)
# Out:
#                      category_3  rating
# 0            Cables&Accessories     5.0
# 1   Keyboards,Mice&InputDevices     5.0
# 2        SmallKitchenAppliances     4.8
# 3          WaterHeaters&Geysers     4.8
# 4        SmallKitchenAppliances     4.8
# 5          WaterHeaters&Geysers     4.7
# 6        SmallKitchenAppliances     4.7
# 7                   Televisions     4.7
# 8        SmallKitchenAppliances     4.7
# 9             MobileAccessories     4.7
# 10       SmallKitchenAppliances     4.7
# 11  Keyboards,Mice&InputDevices     4.6
# 12                  Accessories     4.6
# 13      Vacuum,Cleaning&Ironing     4.6
# 14                  RoomHeaters     4.6
# 15   WaterPurifiers&Accessories     4.6
# 16          PCGamingPeripherals     4.6
# 17  Keyboards,Mice&InputDevices     4.6
# 18          PCGamingPeripherals     4.6
# 19            MobileAccessories     4.6

# %%
data2=xx.loc[0:20]



plt.figure(figsize=(10, 6))
sns.barplot(x='rating', y='category_3', data=data2, palette='viridis',orient='h')

plt.title('Top 20 Ratings by Category')
plt.xlabel('Category')
plt.ylabel('Rating')

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Total Sell of Each Category

# %%
result1.reset_index(inplace=True)

# Plotting a bar chart using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='category_3', y='mean', data=result1, color='skyblue')


# Set titles and labels
plt.title('Total Sell Each Category')
plt.xlabel('Category')
plt.ylabel('Total Sell')
plt.legend()

# Show the plot
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Mean and Minimum Sell of each category

# %%
result1 = df.groupby('category_3')['Price'].agg(['mean', 'min'])
result1['mean'] = result1['mean'].round(2)
result1
# Out:
#                                      mean          min
# category_3
# Accessories                  7.353092e+06       4625.0
# Adapters                     7.653520e+05     229460.0
# AirConditioners              1.389007e+08  138900690.0
# AirPurifiers                 4.039344e+07   29374974.0
# Audio&VideoAccessories       1.291439e+07     557996.0
# Cables&Accessories           4.999563e+06       1995.0
# Calculators                  4.993237e+06    2367910.0
# Coffee,Tea&Espresso          2.013796e+06      42365.0
# Drawing&PaintingSupplies     2.380050e+06    2380050.0
# DrawingMaterials             7.315920e+05     498564.0
# Fans                         1.764632e+07     952403.0
# Flashes                      1.035344e+07   10353442.0
# HardDriveAccessories         1.459267e+06    1459267.0
# Headphones                   6.146239e+07      82194.0
# HealthMonitors               3.293037e+06    3293037.0
# Inks,Toners&Cartridges       2.631637e+06     750483.0
# InteriorAccessories          2.615002e+06    2615002.0
# Keyboards,Mice&InputDevices  1.026938e+07       3675.0
# KitchenTools                 5.384204e+07   53842037.0
# LaptopAccessories            5.572347e+06      17595.0
# LaundryOrganization          1.417203e+06      18020.0
# MediaStreamingDevices        1.052576e+06    1052576.0
# MemoryCards                  7.216567e+07   12038625.0
# MobileAccessories            1.627802e+07       3066.0
# NetworkAdapters              3.115263e+07      35534.0
# PCGamingPeripherals          1.117325e+07     619752.0
# PaintingMaterials            1.744398e+06    1375773.0
# Paper                        9.560660e+05      38412.0
# Parts&Accessories            2.463276e+06    2463276.0
# Printers                     3.655684e+07   30490548.0
# RoomHeaters                  2.425402e+06       2598.0
# SatelliteEquipment           4.318154e+06     390999.0
# Scrapbooking                 1.921140e+06    1921140.0
# SecurityCameras              9.185598e+07    3758120.0
# SewingMachines&Accessories   3.419101e+07    1583428.0
# SmallKitchenAppliances       1.452118e+07       1673.0
# Smartphones&BasicMobiles     3.909591e+08     999750.0
# Speakers                     2.792768e+07     333982.0
# TabletAccessories            4.734935e+06     253930.0
# Televisions                  2.537159e+08     767360.0
# USBGadgets                   2.990382e+05      21449.0
# Vacuum,Cleaning&Ironing      1.336723e+07        398.0
# WaterHeaters&Geysers         1.907866e+07      27512.0
# WaterPurifiers&Accessories   2.781200e+07       7141.0

# %%
result1.reset_index(inplace=True)

result_melted = result1.melt(id_vars='category_3', var_name='Stat', value_name='Price')

plt.figure(figsize=(10, 6))
sns.lineplot(x='category_3', y='Price', hue='Stat', data=result_melted, marker='o')

plt.title('Price Summary by Category')
plt.xlabel('Category')
plt.ylabel('Total Sell')
plt.legend(title='Statistic')

plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Actual Price vs Discount Price Chart

# %%
# Plotting a bar chart using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='category_3', y='actual_price', data=df, color='skyblue', label='Actual_Price')
sns.barplot(x='category_3', y='discounted_price', data=df, color='salmon', alpha=0.7, label='Discount_Price')


# Set titles and labels
plt.title('Actual Price Vs Discount Price')
plt.xlabel('Category')
plt.ylabel('Prices')
plt.legend()

# Show the plot
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # My Other Most Upvoted Notebooks:
# #### Visit My Website Codersaim.com for more.
# #### ** Please Upvote If You Find the Notebook Helpful **
#
# * [**All Necessary Code of Pandas**](https://www.kaggle.com/code/rafsunahmad/all-necessary-code-of-pandas)
# * [**Everything About EDA Using Seaborn & Matplotlib**](https://www.kaggle.com/code/rafsunahmad/everything-about-eda-using-seaborn-matplotlib)
# * [**Full Guide Feature Scaling Theory + Code**](https://www.kaggle.com/code/rafsunahmad/full-guide-feature-scaling)
# * [**Popular Regression Algorithms Theory + Code**](https://www.kaggle.com/code/rafsunahmad/regression-algorithms-theory-code)
# * [**Popular Classification Algorithms Theory + Code**](https://www.kaggle.com/code/rafsunahmad/classification-algorithms-theory-code)
# * [**Everything About Multicollinearity Theory + Code**](https://www.kaggle.com/code/rafsunahmad/everything-about-multicollinearity-theory-code)
# * [**Common Features Selection Methods Theory + Code**](https://www.kaggle.com/code/rafsunahmad/common-features-selection-methods-theory-code)
# * [**All Model Evaluation Techniques Theory + Code**](https://www.kaggle.com/code/rafsunahmad/all-model-evaluation-techniques-theory-code)
# * [**All Popular Clustering Methods Theory + Code**](https://www.kaggle.com/code/rafsunahmad/all-popular-clustering-methods-theory-code)
# * [**Cross Validation All Techniques Theory + Code**](https://www.kaggle.com/code/rafsunahmad/cross-validation-all-techniques-theory-code)
# * [**All Ensemble Learning Methods Theory + Code**](https://www.kaggle.com/code/rafsunahmad/all-ensemble-learning-methods-theory-code)
# * [**ANN Ultimate Guide( All You Need to Know)**](https://www.kaggle.com/code/rafsunahmad/ann-ultimate-guide-all-you-need-to-know)
# * [**CNN Ultimate Guide( All You Need to Know)**](https://www.kaggle.com/code/rafsunahmad/cnn-ultimate-guide-all-you-need-to-know)
# * [**VGG16 & Alex net Working Process Guide**](https://www.kaggle.com/code/rafsunahmad/vgg16-alex-net-working-process-guide)
# * [**RNN Ultimate Guide( All You Need to Know)**](https://www.kaggle.com/code/rafsunahmad/rnn-ultimate-guide-all-you-need-to-know)
# * [**Transformer Model Complete Guide**](https://www.kaggle.com/code/rafsunahmad/transformer-model-complete-guide)
# * [**Amazon Data Analysis**](https://www.kaggle.com/code/rafsunahmad/amazon-data-analysis)
# * [**News Category Classifier Accuracy-83%**](https://www.kaggle.com/code/rafsunahmad/news-category-classifier-accuracy-83)
# * [**Australian Vehicle Prices Prediction accuracy=86%**](https://www.kaggle.com/code/rafsunahmad/australian-vehicle-prices-prediction-accuracy-86)
# * [**Terrorist Attack Complete EDA**](https://www.kaggle.com/code/rafsunahmad/terrorist-attack-complete-eda)
# * [**Customer Behavior Classification + EDA**](https://www.kaggle.com/code/rafsunahmad/customer-behavior-classification-eda)
# * [**Heart Disease Complete EDA + accuracy =98%**](https://www.kaggle.com/code/rafsunahmad/heart-disease-complete-eda-accuracy-98)
